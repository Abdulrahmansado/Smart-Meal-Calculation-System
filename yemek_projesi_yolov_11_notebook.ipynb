# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulrahmansado/Smart-Meal-Calculation-System/blob/main/yemek_projesi_yolov_11_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics # Use pip directly to install the package.
import ultralytics
ultralytics.checks()

# %%
#content klasoru altinda datasets adinda yeni klasor olustur
import os
os.makedirs("/content/datasets", exist_ok=True)
# %cd /content/datasets

# %%
# roboflow da bulunan ozel datasetimizi projeye dahil et
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="zVmUONqHpxBZmfzuhBCl")
project = rf.workspace("abdulrahman-5zzoy").project("food-detection-b5zgs")
version = project.version(1)
dataset = version.download("yolov11")

# %%
#yolo11n.pt modeli hakkinda bilgi verir
# !yolo val model=/content/yolo11n.pt data=/content/food-detection-1/data.yaml

# %%
#model egitime baslatilir epoches 50 defa egitim tekrar yapilir
# !yolo train model=/content/yolo11n.pt data=/content/food-detection-1/data.yaml epochs=50 imgsz=640

# %%
#yolo11n.pt modelini onnx formatina donustur
# !yolo export model=yolo11n.pt format=onnx

# %%
#modelin sonucunu iceren matrix fotografi goster
from IPython.display import Image
Image(filename='/content/runs/detect/val/confusion_matrix.png', width=600)

# %%
##modelin sonucunu iceren matrix fotografi goster
Image(filename='/content/runs/detect/train2/val_batch0_labels.jpg', width=600)

# %%
#%cd {HOME}
Image(filename='/content/runs/detect/train2/confusion_matrix.png', width=600)

# %%
#best.pt modelini kullanarak foof deection dateseti uzerinde deneme yapilir
# !yolo task=detect mode=val model=/content/runs/detect/train2/weights/best.pt data=/content/food-detection-1/data.yaml

# %%
#best.pt modelini kullanarak foof deection dateseti uzerinde deneme yapilir
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source=/content/food-detection-1/test/images save=True

# %%
# best.pt modelini onnx formatina donustur
# !yolo export model=/content/runs/detect/train2/weights/best.pt format=onnx

# %%
#best.onnx modelini kullanarak test klasorunde bulunan fotograflar uzerinde deneme yap
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.onnx conf=0.25 source=/content/food-detection-1/test/images save=True
